# %%
from sgdlmodel import analysis
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# path = 'results/BEST/*.pickle'
# path = 'results/BESTHIGHGPU/*.pickle'
path = 'results/*.pickle'

    
picklefile = []
for file in glob.glob(path):  
    picklefile.append(file) 
print(len(picklefile))
k=4
picklefile =sorted(picklefile, key=lambda x: float(x.split('_')[k][len("testpsnr"):len("testpsnr2.0129e+01")]), reverse=True)

for file in picklefile:
    #resave(file)
    print(file)

LossPsnr_print = True
Fig_print = True
num = 3
for i in range(num):
    filepath = picklefile[i]
    print(f'-------------{filepath}-----------------------')
    analysis(filepath)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 5
# results/SGDL_numlayer12_learningrate5.0000e-03_trainpsnr2.1939e+01_testpsnr2.1833e+01.pickle
# results/SGDL_numlayer12_learningrate5.0000e-04_trainpsnr2.1864e+01_testpsnr2.1765e+01.pickle
# results/SGDL_numlayer12_learningrate1.0000e-03_trainpsnr2.1695e+01_testpsnr2.1589e+01.pickle
# results/SGDL_numlayer12_learningrate1.0000e-02_trainpsnr2.1147e+01_testpsnr2.1090e+01.pickle
# results/SGDL_numlayer12_learningrate1.0000e-04_trainpsnr1.9812e+01_testpsnr1.9772e+01.pickle
# -------------results/SGDL_numlayer12_learningrate5.0000e-03_trainpsnr2.1939e+01_testpsnr2.1833e+01.pickle-----------------------
# Namespace(epoch=10000, learning_rate=0.005, num_layers=12, num_channels=256, interval=25)
# train time is 76.64042925834656
# train PSNR is 21.938703536987305, test PSNR is 21.832502365112305
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# -------------results/SGDL_numlayer12_learningrate5.0000e-04_trainpsnr2.1864e+01_testpsnr2.1765e+01.pickle-----------------------
# Namespace(epoch=10000, learning_rate=0.0005, num_layers=12, num_channels=256, interval=25)
# train time is 79.09435677528381
# train PSNR is 21.863670349121094, test PSNR is 21.765361785888672
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# -------------results/SGDL_numlayer12_learningrate1.0000e-03_trainpsnr2.1695e+01_testpsnr2.1589e+01.pickle-----------------------
# Namespace(epoch=10000, learning_rate=0.001, num_layers=12, num_channels=256, interval=25)
# train time is 78.19475841522217
# train PSNR is 21.69542694091797, test PSNR is 21.588594436645508
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
