# %% [markdown]
# # Guidance for the regression on the manifold data
#
# This file provide a step-to-step guidance to apply MGDL model to manifold data (section 3.2 in the papar).

# %% [markdown]
# ## Data descriptions
# We create a seperate file 'ManifoldsData.py' to generate data.  Readers can dive in this file to see how the data are generated.

# %% [markdown]
# ## Training and testing models
# We create the seperate 'main_run.py' for training models. In this file, there are several parameters need to be setted.
#
# + Amptype: choose from 'increase', 'vary'. In this example, we've explored two settings: 'increase' for setting 1, and 'vary' for setting 2.
#
# + L:  choose from 4, 0. This is the parameter 'q' in equation (9).
#
# + SGD :  choose from 'True' or 'False'. If employing the stochastic method within Adam, set SGD to 'True' and define the minibatch size. Conversely, if utilizing the full gradient in Adam, set SGD to 'False' and minibatch size to 'False'.
#
# + mini_batch : choose from '512', '1024', 'False'. Set the minibatch size.
#
# + mul_layers_dims: [[1, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1]]. This is the structure of MGDL model.
#
# + mul_epochs: [30000, 30000, 30000, 30000]. The total of training epochs in MGDL.
#
# + MIN_learning_rate: choose from '1e-6, 1e-5, 1e-4'. The minimum learning rate, denote as $t_{min}$ in the paper.
#
# + MAX_learning_rate: choose from '1e-4, 5e-4, 1e-3'. The maximum learning rate, denote as $t_{max}$ in the paper.
#
# Once the above parameters setted, we can train our model by run the file 'main_run.py'.

# %% [markdown]
# ##### Training MGDL model by readers
# If readers prefer to train the model themselves, they can utilize the following code and the results will be save in the folder 'results'

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %run main_run.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ----------------------grade : 1---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 2---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 3---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 4---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------

# %% [markdown]
# Reader can analysis and test their own model as follows.

# %%
import glob
from analysis import results_analysis
path = 'results/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    results_analysis(file, figure = True)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# results/Ampincrease_xavier_epoch[300, 300, 300, 300]_minibatchFalse_MAXlearningrate1.0000e-03_MINlearningrate1.0000e-04_validation9.9980e-01_train9.9986e-01_L0.pickle
# ################################################################################################################
# results/Ampincrease_xavier_epoch[300, 300, 300, 300]_minibatchFalse_MAXlearningrate1.0000e-03_MINlearningrate1.0000e-04_validation9.9980e-01_train9.9986e-01_L0.pickle
# {'mul_layers_dims': [[2, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1]], 'lambd_W': [0, 0, 0, 0]}
# {'optimizer': 'adam', 'beta1': 0.9, 'beta2': 0.999, 'epsilon': 1e-08, 'error': 1e-07, 'SGD': False, 'mini_batch_size': False, 'REC_FRQ': 100, 'init_method': 'xavier', 'max_learning_rate': 0.001, 'min_learning_rate': 0.0001, 'epochs': [300, 300, 300, 300], 'activation': 'relu'}
# the train rse for each grade is [0.9999633216691519, 0.9999321095563863, 0.9999014646990003, 0.9998573152458496]
# the validation rse for each grade is [0.9999515641951382, 0.9999095146734562, 0.9998621716343095, 0.9997972893960279]
# the train times for each grade is [55.87925100326538, 80.79610753059387, 80.10173749923706, 80.67163443565369]
# the total train times is 297.44873046875

# %%
import glob
from analysis import test_model
path = 'results/*.pickle'
for file in glob.glob(path):
    print(file)
    test_model(file)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# results/Ampincrease_xavier_epoch[300, 300, 300, 300]_minibatchFalse_MAXlearningrate1.0000e-03_MINlearningrate1.0000e-04_validation9.9980e-01_train9.9986e-01_L0.pickle
# the test rse for each grade is [0.9999721314379211, 0.999946689617123, 0.9999256310605505, 0.9998977784610038]

# %% [markdown]
# ### Using our trained model
#
# We encourage readers to train the model themselves to better understand/test MGDL. However, it reqiures several hours to train a good model. Therefore, it is utilizing our pre-trained model is also a good option, using the following code. We also create a seperate 'analysis.py' to analysis and test our trained model.

# %%
import glob
from analysis import results_analysis
Amptype = "increase_q0"
path = 'TrainedModel/{}/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    results_analysis(file, figure=True)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# TrainedModel/increase_q0/increase_xavier_epoch[30000, 30000, 30000, 30000]_minibatchFalse_MAXlearningrate1.0000e-03_MINlearningrate1.0000e-04_validation2.6553e-04_train1.9345e-04_L0.pickle
# ################################################################################################################
# TrainedModel/increase_q0/increase_xavier_epoch[30000, 30000, 30000, 30000]_minibatchFalse_MAXlearningrate1.0000e-03_MINlearningrate1.0000e-04_validation2.6553e-04_train1.9345e-04_L0.pickle
# {'mul_layers_dims': [[2, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1]], 'lambd_W': [0, 0, 0, 0]}
# {'optimizer': 'adam', 'beta1': 0.9, 'beta2': 0.999, 'epsilon': 1e-08, 'error': 1e-07, 'SGD': False, 'mini_batch_size': False, 'REC_FRQ': 100, 'init_method': 'xavier', 'max_learning_rate': 0.001, 'min_learning_rate': 0.0001, 'epochs': [30000, 30000, 30000, 30000]}
# the train rse for each grade is [0.9689341217447323, 0.6185436076196705, 0.12313791113522231, 0.0001934517270392834]
# the validation rse for each grade is [0.9652935632022559, 0.6071811213247245, 0.10448693557507073, 0.00026552665463705196]
# the train times for each grade is [3417.3584842681885, 4104.163840770721, 4175.690169095993, 4271.71927690506]
# the total train times is 15968.931771039963

# %% [markdown]
# # Test model
# After training the model, we employ the test data to evaluate its performance. It's important to emphasize that this test data is never involved in the training process.

# %%
import glob
from analysis import test_model
Amptype = "increase_q0"
path = 'TrainedModel/{}/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    test_model(file)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# TrainedModel/increase_q0/increase_xavier_epoch[30000, 30000, 30000, 30000]_minibatchFalse_MAXlearningrate1.0000e-03_MINlearningrate1.0000e-04_validation2.6553e-04_train1.9345e-04_L0.pickle
# the test rse for each grade is [0.9685221049117322, 0.6156536824605812, 0.11737777572825547, 0.00021104908033607985]
