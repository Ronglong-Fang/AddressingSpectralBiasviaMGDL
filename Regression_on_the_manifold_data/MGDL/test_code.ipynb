# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %run main_run.py
# Out:
# ----------------------grade : 1---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 2---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 3---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 4---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ...
