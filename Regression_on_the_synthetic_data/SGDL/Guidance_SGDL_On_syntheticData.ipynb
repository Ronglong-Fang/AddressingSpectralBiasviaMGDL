# %% [markdown]
# # Guidance for the regression on the synthetic data
#
# This file provide a step-to-step guidance to apply SGDL model to synthetic data (section 3.1 in the papar).

# %% [markdown]
# ## Data descriptions
# We create a seperate file 'SpectralBiasData.py' to generate data.  Readers can dive in this file to see how the data are generated.

# %% [markdown]
# ## Training and testing models
# We create the seperate 'main_run.py' for training models. In this file, there are several parameters need to be setted.
#
# + Amptype: choose from 'constant', 'decrease', 'vary', 'increase'. In this example, we've explored four settings: 'constant' for setting 1, 'decrease' for setting 2, 'vary' for setting 3, and 'increase' for setting 4.
#
# + SGD :  choose from 'True' or 'False'. If employing the stochastic method within Adam, set SGD to 'True' and define the minibatch size. Conversely, if utilizing the full gradient in Adam, set SGD to 'False' and minibatch size to 'False'.
#
# + mini_batch : choose from '256', '512', 'Full'. Set the minibatch size.
#
# + mul_layers_dims: [1, 256, 256, 256, 256, 256, 256, 256, 256, 1]. This is the structure of SGDL for setting 1, 2, and 3. The strcuture for setting 4 is provide in 'main_run.py'
#
# + mul_epochs: 30000. The total of training epochs in MGDL.
#
# + MIN_learning_rate: choose from '1e-7, 1e-6, 1e-5, 1e-4'. The minimum learning rate, denote as $t_{min}$ in the paper.
#
# + MAX_learning_rate: choose from '5e-5, 1e-5, 1e-4, 5e-4, 1e-3'. The maximum learning rate, denote as $t_{max}$ in the paper.
#
# Once the above parameters setted, we can train our model by run the file 'main_run.py'.

# %% [markdown]
# ##### Training SGDL model by readers
# If readers prefer to train the model themselves, they can utilize the following code and the results will be save in the folder 'results'

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %run main_run.py
# Out:
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------

# %% [markdown]
# Reader can analysis and test their own model as follows.

# %%
import glob
from analysis import results_analysis
path = 'results/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    results_analysis(file)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# results/Ampdecrease_xavier_single_epochs300_MAXlearningrate1.00e-03_MINlearningrate1.00e-04_validation9.5154e-01_train9.5063e-01_minibatchzieFalse.pickle
# ###########################################################################
# results/Ampdecrease_xavier_single_epochs300_MAXlearningrate1.00e-03_MINlearningrate1.00e-04_validation9.5154e-01_train9.5063e-01_minibatchzieFalse.pickle
# {'layers_dims': [1, 256, 256, 256, 256, 256, 256, 256, 256, 1], 'lambd_W': 0, 'sinORrelu': 0, 'activation': 'relu', 'init_method': 'xavier'}
# {'optimizer': 'adam', 'beta1': 0.9, 'beta2': 0.999, 'epsilon': 1e-08, 'error': 1e-07, 'max_learning_rate': 0.001, 'min_learning_rate': 0.0001, 'epochs': 300, 'REC_FRQ': 100, 'SGD': False, 'mini_batch_size': False}
# train_rse is 0.950634380913416, validation_rses is 0.951538294179984, test_rse is 0.9472463272730669
# the train time is 144.756249666214
# at epochs 0, train rse 1.0000086895230365, validation rse 1.0001495865861196
# train time at epochs 0 is 0.2927417755126953

# %%
import glob
from analysis import test_model
Amptype = "decrease"
path = 'results/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    test_model(file)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# results/Ampdecrease_xavier_single_epochs300_MAXlearningrate1.00e-03_MINlearningrate1.00e-04_validation9.5154e-01_train9.5063e-01_minibatchzieFalse.pickle
# the test rse for each grade is 0.9472463272730669

# %% [markdown]
# ### Using our trained model
#
# We encourage readers to train the model themselves to better understand/test MGDL. However, it reqiures several hours to train a good model. Therefore, it is utilizing our pre-trained model is also a good option, using the following code. We also create a seperate 'analysis.py' to analysis and test our trained model.

# %%
import glob
from analysis import results_analysis
Amptype = "decrease"
path = 'TrainedModel/{}/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    results_analysis(file)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# TrainedModel/decrease/decrease_xavier_single_epochs30000_MAXlearningrate5.00e-04_MINlearningrate1.00e-04_validation5.8689e-03_train5.7773e-03_minibatchzie256.pickle
# ###########################################################################
# TrainedModel/decrease/decrease_xavier_single_epochs30000_MAXlearningrate5.00e-04_MINlearningrate1.00e-04_validation5.8689e-03_train5.7773e-03_minibatchzie256.pickle
# {'layers_dims': [1, 256, 256, 256, 256, 256, 256, 256, 256, 1], 'lambd_W': 0, 'sinORrelu': 0, 'activation': 'relu', 'init_method': 'xavier'}
# {'optimizer': 'adam', 'beta1': 0.9, 'beta2': 0.999, 'epsilon': 1e-08, 'error': 1e-07, 'max_learning_rate': 0.0005, 'min_learning_rate': 0.0001, 'epochs': 30000, 'REC_FRQ': 100, 'SGD': True, 'mini_batch_size': 256}
# train_rse is 0.005777251456160306, validation_rses is 0.005868916439417916
# the train time is 32053.585393190384
# at epochs 0, train rse 1.0000086895230365, validation rse 1.0001495865861194
# train time at epochs 0 is 0.205336332321167
# at epochs 10000, train rse 0.08696700617625742, validation rse 0.07464337371075719
# train time at epochs 10000 is 10277.148934364319
# at epochs 20000, train rse 0.019565270982132017, validation rse 0.01928472178086748
# train time at epochs 20000 is 20739.81484770775
# at epochs 30000, train rse 0.005777251456160306, validation rse 0.005868916439417916
# train time at epochs 30000 is 32053.585393190384

# %% [markdown]
# # Test model
# After training the model, we employ the test data to evaluate its performance. It's important to emphasize that this test data is never involved in the training process.

# %%
import glob
from analysis import test_model
Amptype = "constant"
path = 'TrainedModel/{}/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    test_model(file)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# TrainedModel/constant/constant_xavier_single_epochs30000_MAXlearningrate1.00e-04_MINlearningrate1.00e-04_validation1.3572e-01_train1.4936e-01_minibatchzie256.pickle
# the test rse for each grade is 0.1181193269381385
