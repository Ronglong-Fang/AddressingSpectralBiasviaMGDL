# %% [markdown]
# # Guidance for the regression on the synthetic data
#
# This file provide a step-to-step guidance to apply MGDL model to synthetic data (section 3.1 in the papar).

# %% [markdown]
# ## Data descriptions
# We create a seperate file 'SpectralBiasData.py' to generate data.  Readers can dive in this file to see how the data are generated.

# %% [markdown]
# ## Training and testing models
# We create the seperate 'main_run.py' for training models. In this file, there are several parameters need to be setted.
#
# + Amptype: choose from 'constant', 'decrease', 'vary',  'increase'. In this example, we've explored four settings: 'constant' for setting 1, 'decrease' for setting 2,
#   'vary' for setting 3, 'increase' for setting 4.
#
# + SGD :  choose from 'True' or 'False'. If employing the stochastic method within Adam, set SGD to 'True' and define the minibatch size. Conversely, if utilizing the full gradient in Adam, set SGD to 'False' and minibatch size to 'False'.
#
# + mini_batch : choose from '256', '512', 'Full'. Set the minibatch size.
#
# + mul_layers_dims: [[1, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1]]. This is MGDL structure for settings 1, 2, and 3. The structure for setting 4 is provided file 'main_run.py'
#
# + mul_epochs: [30000, 30000, 30000, 30000]. The total of training epochs in MGDL  for settings 1, 2, and 3.  The train epoch for setting 4 is provided file 'main_run.py'
#
# + MIN_learning_rate: choose from '1e-7, 1e-6, 1e-5, 1e-4'. The minimum learning rate, denote as $t_{min}$ in the paper.
#
# + MAX_learning_rate: choose from '5e-5, 1e-5, 1e-4, 5e-4, 1e-3'. The maximum learning rate, denote as $t_{max}$ in the paper.
#
# Once the above parameters setted, we can train our model by run the file 'main_run.py'.

# %% [markdown]
# ##### Training MGDL model by readers
# If readers prefer to train the model themselves, they can utilize the following code and the results will be save in the folder 'results'

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %run main_run.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ----------------------grade : 1---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 2---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 3---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 4---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------

# %% [markdown]
# Reader can analysis and test their own model as follows.

# %%
import glob
from analysis import results_analysis
path = 'results/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    results_analysis(file, figure = False)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# results/Ampdecrease_xavier_epoch[300, 300, 300, 300]_minibatchFalse_MAXlearningrate1.0000e-03_MINlearningrate1.0000e-04_validation6.6891e-01_train6.8274e-01.pickle
# ################################################################################################################
# results/Ampdecrease_xavier_epoch[300, 300, 300, 300]_minibatchFalse_MAXlearningrate1.0000e-03_MINlearningrate1.0000e-04_validation6.6891e-01_train6.8274e-01.pickle
# {'mul_layers_dims': [[1, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1]], 'lambd_W': [0, 0, 0, 0]}
# {'optimizer': 'adam', 'beta1': 0.9, 'beta2': 0.999, 'epsilon': 1e-08, 'error': 1e-07, 'SGD': False, 'mini_batch_size': False, 'REC_FRQ': 100, 'init_method': 'xavier', 'max_learning_rate': 0.001, 'min_learning_rate': 0.0001, 'epochs': [300, 300, 300, 300]}
# the train rse for each grade is [0.9894037709605114, 0.9434624353892586, 0.8480570167885394, 0.682737222964937]
# the validation rse for each grade is [0.9871048254011457, 0.9352376004230882, 0.83198120165393, 0.6689060643435332]
# the train times for each grade is [27.115668058395386, 40.593005657196045, 40.599705934524536, 40.453290700912476]
# the total train times is 148.76167035102844

# %%
import glob
from analysis import test_model
Amptype = "decrease"
path = 'results/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    test_model(file)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# results/Ampdecrease_xavier_epoch[300, 300, 300, 300]_minibatchFalse_MAXlearningrate1.0000e-03_MINlearningrate1.0000e-04_validation6.6891e-01_train6.8274e-01.pickle
# the test rse for each grade is [0.9955622271330765, 0.9476620714873787, 0.8510271667997766, 0.6842727459097059]

# %% [markdown]
# ### Using our trained model
#
# We encourage readers to train the model themselves to better understand/test MGDL. However, it reqiures several hours to train a good model. Therefore, it is utilizing our pre-trained model is also a good option, using the following code. We also create a seperate 'analysis.py' to analysis and test our trained model.

# %%
import glob
from analysis import results_analysis
Amptype = "decrease"
path = 'TrainedModel/{}/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    results_analysis(file, figure=True)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# TrainedModel/decrease/decrease_xavier_epoch[30000, 30000, 30000, 30000]_minibatch256_MAXlearningrate1.0000e-04_MINlearningrate1.0000e-04_validation3.9923e-06_train1.4742e-06.pickle
# ################################################################################################################
# TrainedModel/decrease/decrease_xavier_epoch[30000, 30000, 30000, 30000]_minibatch256_MAXlearningrate1.0000e-04_MINlearningrate1.0000e-04_validation3.9923e-06_train1.4742e-06.pickle
# {'mul_layers_dims': [[1, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1], [256, 256, 256, 1]], 'lambd_W': [0, 0, 0, 0]}
# {'optimizer': 'adam', 'beta1': 0.9, 'beta2': 0.999, 'epsilon': 1e-08, 'error': 1e-07, 'SGD': True, 'mini_batch_size': 256, 'REC_FRQ': 100, 'init_method': 'xavier', 'max_learning_rate': 0.0001, 'min_learning_rate': 0.0001, 'epochs': [30000, 30000, 30000, 30000]}
# the train rse for each grade is [0.6707269485690384, 0.07122373542718642, 0.0002007189537967685, 1.4742244372603165e-06]
# the validation rse for each grade is [0.6518499199397196, 0.06464332858516622, 0.00019472353244696185, 3.992314987447208e-06]
# the train times for each grade is [4319.595772027969, 8106.594378948212, 7919.666965961456, 7282.842890262604]
# the total train times is 27628.70000720024

# %% [markdown]
# # Test model
# After training the model, we employ the test data to evaluate its performance. It's important to emphasize that this test data is never involved in the training process.

# %%
import glob
from analysis import test_model
Amptype = "decrease"
path = 'TrainedModel/{}/*.pickle'.format(Amptype)
for file in glob.glob(path):
    print(file)
    test_model(file)  #if figure is True, the loss and training process will display, otherwise only display loss
# Out:
# TrainedModel/decrease/decrease_xavier_epoch[30000, 30000, 30000, 30000]_minibatch256_MAXlearningrate1.0000e-04_MINlearningrate1.0000e-04_validation3.9923e-06_train1.4742e-06.pickle
# the test rse for each grade is [0.6661830743561122, 0.08063867359569904, 0.00019640088183771375, 6.536652927883334e-06]
